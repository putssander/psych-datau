# %% [markdown]
# # Check differences

# %%
# !pip install openpyxl
import pandas as pd

# %%
in_a = './../resources/data_ignored/Verena/report.3559000.14321-5_VOOR.csv'
in_b = './../resources/data_ignored/Sanne 07052020/report.3559000_VOOR.csv'

# in_a = './../resources/data_ignored/Sanne 07052020/report.3694000_NA.csv' 
# in_b = './../resources/data_ignored/Verena/report.3694000.14321-7_NA.csv'

# in_a = './../resources/data_ignored/Sanne 07052020/report.merged-sanne-binge.xlsx'
# in_b = './../resources/data_ignored/Verena/mEMA_merged_VJ_06052020.xlsx'

# df_a = pd.read_excel(in_a)
# df_b = pd.read_excel(in_b)

df_a = pd.read_csv(in_a)
df_b = pd.read_csv(in_b)

instances_set_a = df_a['instance_key'].tolist()
instances_set_b = df_b['instance_key'].tolist()

diff_a = list(set(instances_set_a) - set(instances_set_b))
diff_b = list(set(instances_set_b) - set(instances_set_a))

print(diff_a)
print(diff_b)
# Out:
# []
# ...
